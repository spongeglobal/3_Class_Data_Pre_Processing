# %%
import pandas as pd
import numpy as np
import xarray as xr

# %%
x= np.array([(85,60,90),
             (73,80,64),
             (98,58,74),
             (88,96,87)])

df=pd.DataFrame(x)
print(df)
# Out:
#     0   1   2
# 0  85  60  90
# 1  73  80  64
# 2  98  58  74
# 3  88  96  87

# %%
df.head()
# Out:
#     0   1   2
# 0  85  60  90
# 1  73  80  64
# 2  98  58  74
# 3  88  96  87

# %%
df.to_csv('sample_data/mydata.csv', index=False)
