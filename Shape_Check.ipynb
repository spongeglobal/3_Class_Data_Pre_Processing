# %%
import pandas as pd

#create DataFrame
df = pd.DataFrame({'team': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
                   'position': ['G', 'G', 'F', 'G', 'F', 'C', 'G', 'F', 'C'],
                   'points': [5, 7, 7, 9, 12, 9, 9, 4, 13],
                   'rebounds': [11, 8, 10, 6, 6, 5, 9, 12, 10]})

#view DataFrame
df
# Out:
#   team position  points  rebounds
# 0    A        G       5        11
# 1    A        G       7         8
# 2    A        F       7        10
# 3    B        G       9         6
# 4    B        F      12         6
# 5    B        C       9         5
# 6    C        G       9         9
# 7    C        F       4        12
# 8    C        C      13        10

# %%
df.shape #ROW_C check (Rows and then Columns)
# Out:
# (9, 4)
